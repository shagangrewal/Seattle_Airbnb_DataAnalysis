# %%
#importing all the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
#Reading the csv files into the respective dataframes

df_calendar = pd.read_csv(r'C:\Users\grewa\Downloads\archive\calendar.csv')
df_listings = pd.read_csv(r'C:\Users\grewa\Downloads\archive\listings.csv')
df_reviews = pd.read_csv(r'C:\Users\grewa\Downloads\archive\reviews.csv')

# %%
#Understanding Calendar Dataset
df_calendar.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
df_calendar.shape
# Out:
# (1393570, 4)

# %%
#Understanding Listings dataset
df_listings.head(3)
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
#
# ...

# %%
df_listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'notes', 'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
# ...

# %%
df_listings.shape
# Out:
# (3818, 92)

# %%
df_listings.describe()
# Out:
#                  id     scrape_id       host_id  host_listings_count  \
# count  3.818000e+03  3.818000e+03  3.818000e+03          3816.000000
# mean   5.550111e+06  2.016010e+13  1.578556e+07             7.157757
# std    2.962660e+06  0.000000e+00  1.458382e+07            28.628149
# min    3.335000e+03  2.016010e+13  4.193000e+03             1.000000
# 25%    3.258256e+06  2.016010e+13  3.275204e+06             1.000000
# 50%    6.118244e+06  2.016010e+13  1.055814e+07             1.000000
# 75%    8.035127e+06  2.016010e+13  2.590309e+07             3.000000
# max    1.034016e+07  2.016010e+13  5.320861e+07           502.000000
#
#        host_total_listings_count     latitude    longitude  accommodates  \
# count                3816.000000  3818.000000  3818.000000   3818.000000
# mean                    7.157757    47.628961  -122.333103      3.349398
# std                    28.628149     0.043052     0.031745      1.977599
# ...

# %%
#Lets visualize some data to understanding so many columns
#plotting historgram for the same

fig = plot.figure(figsize = (16,22))
axes = fig.gca() 
df_listings.hist(ax=axes)
# Out:
# C:\Users\grewa\AppData\Local\Temp/ipykernel_28964/3782371545.py:6: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df_listings.hist(ax=axes)
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'scrape_id'}>,
#         <AxesSubplot:title={'center':'host_id'}>,
#         <AxesSubplot:title={'center':'host_listings_count'}>,
#         <AxesSubplot:title={'center':'host_total_listings_count'}>],
#        [<AxesSubplot:title={'center':'latitude'}>,
#         <AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'accommodates'}>,
#         <AxesSubplot:title={'center':'bathrooms'}>,
#         <AxesSubplot:title={'center':'bedrooms'}>],
#        [<AxesSubplot:title={'center':'beds'}>,
#         <AxesSubplot:title={'center':'square_feet'}>,
#         <AxesSubplot:title={'center':'guests_included'}>,
#         <AxesSubplot:title={'center':'minimum_nights'}>,
# ...

# %%
#using correlation heatmap to figure the important columns for our model to answer the business questions
fig, axes  = plot.subplots(figsize=(15,15))
sns.heatmap(df_listings.corr(),annot=True, fmt='.1f',ax = axes)
# Out:
# <AxesSubplot:>

# %%
#as visible from the heatmap above, a lot of variables are not correlated
#below code is used to take less correlated variables and then eliminate the ones which are not useful for us
#this can be referred to as feature selection as only the features important to the data will be dropped

not_to_drop = [ 'id','host_id', 'host_since', 'host_is_superhost', 'host_listings_count', 'host_total_listings_count', 'neighbourhood_cleansed', 'property_type', 'room_type',
       'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'amenities','price', 'guests_included', 'minimum_nights', 'maximum_nights', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'cancellation_policy', 'review_scores_value', 'calculated_host_listings_count',
       'reviews_per_month']

to_drop = [col for col in df_listings.columns if col not in not_to_drop]

listings_subset = df_listings.drop(to_drop,axis=1)

listings_subset.shape
# Out:
# (3818, 29)

# %%
listings_subset.columns
# Out:
# Index(['id', 'host_id', 'host_since', 'host_is_superhost',
#        'host_listings_count', 'host_total_listings_count',
#        'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'amenities', 'price', 'guests_included', 'minimum_nights',
#        'maximum_nights', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'review_scores_value', 'cancellation_policy',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
#understanding the reviews dataset
df_reviews.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
#dropping the reviewer name as it 
reviews_subset = df_reviews.drop(['reviewer_name'],axis=1)

# %%
#newer data frame, subset of the review df
reviews_subset.shape
# Out:
# (84849, 5)

# %%
#checking with the previous reviews dataset
df_reviews.shape
# Out:
# (84849, 6)

# %%
reviews_subset.columns
# Out:
# Index(['listing_id', 'id', 'date', 'reviewer_id', 'comments'], dtype='object')

# %%
listings_subset['price'].head()
# Out:
# 0     $85.00
# 1    $150.00
# 2    $975.00
# 3    $100.00
# 4    $450.00
# Name: price, dtype: object

# %%
#Cleaning and transformation of data
#price is object type(categorical data) converting it to float

object_to_float = lambda col: col.replace('$','').replace(',','')
listings_subset['price'] = listings_subset['price'].apply(object_to_float).astype(float)

# %%
df_calendar.isna().mean()
# Out:
# listing_id    0.00000
# date          0.00000
# available     0.00000
# price         0.32939
# dtype: float64

# %%
#dropping the NaN values from the dataset
df_calendar = df_calendar.dropna()

# %%
#checking for futher NaN values in the dataset
df_calendar.isna().mean()
# Out:
# listing_id    0.0
# date          0.0
# available     0.0
# price         0.0
# dtype: float64

# %%
#transforming the price column for the caledar df as well
df_calendar['price'] = df_calendar['price'].apply(object_to_float).astype(float)

# %%
df_calendar['price'].head()
# Out:
# 0     85.0
# 1     85.0
# 9     85.0
# 10    85.0
# 14    85.0
# Name: price, dtype: float64

# %%
#convert date time format to yyyy-mm-dd
convert_date = lambda col: pd.to_datetime(col, yearfirst=True, format='%Y-%m-%d')

df_calendar['date'] = df_calendar['date'].apply(convert_date)

# %%
df_calendar['date'].head()
# Out:
# 0    2016-01-04
# 1    2016-01-05
# 9    2016-01-13
# 10   2016-01-14
# 14   2016-01-18
# Name: date, dtype: datetime64[ns]

# %%
#transforming the host since column to desired date time format
listings_subset['host_since'] = listings_subset['host_since'].apply(convert_date)

# %%
listings_subset['host_since'].head()
# Out:
# 0   2011-08-11
# 1   2013-02-21
# 2   2014-06-12
# 3   2013-11-06
# 4   2011-11-29
# Name: host_since, dtype: datetime64[ns]

# %%
reviews_subset['date'] = reviews_subset['date'].apply(convert_date)

# %%
reviews_subset['date'].head()
# Out:
# 0   2015-07-19
# 1   2015-07-20
# 2   2015-07-26
# 3   2015-08-02
# 4   2015-08-10
# Name: date, dtype: datetime64[ns]

# %%
#creating a lambda function for converting object type to categorical type
to_category = lambda col: col.astype('category')

# %%
listings_subset[listings_subset.select_dtypes(['object']).columns] = listings_subset.select_dtypes(['object']).apply(to_category)

# %%
listings_subset.dtypes
# Out:
# id                                         int64
# host_id                                    int64
# host_since                        datetime64[ns]
# host_is_superhost                       category
# host_listings_count                      float64
# host_total_listings_count                float64
# neighbourhood_cleansed                  category
# latitude                                 float64
# longitude                                float64
# property_type                           category
# room_type                               category
# accommodates                               int64
# bathrooms                                float64
# bedrooms                                 float64
# beds                                     float64
# amenities                               category
# price                                    float64
# guests_included                            int64
# minimum_nights                             int64
# ...

# %%
listings_subset.isna().mean()
# Out:
# id                                0.000000
# host_id                           0.000000
# host_since                        0.000524
# host_is_superhost                 0.000524
# host_listings_count               0.000524
# host_total_listings_count         0.000524
# neighbourhood_cleansed            0.000000
# latitude                          0.000000
# longitude                         0.000000
# property_type                     0.000262
# room_type                         0.000000
# accommodates                      0.000000
# bathrooms                         0.004191
# bedrooms                          0.001572
# beds                              0.000262
# amenities                         0.000000
# price                             0.000000
# guests_included                   0.000000
# minimum_nights                    0.000000
# maximum_nights                    0.000000
# availability_30                   0.000000
# availability_60                   0.000000
# ...

# %%
reviews_subset.isna().mean()
# Out:
# listing_id     0.000000
# id             0.000000
# date           0.000000
# reviewer_id    0.000000
# comments       0.000212
# dtype: float64

# %%
listings_subset['property_type'].dtypes
# Out:
# CategoricalDtype(categories=['Apartment', 'Bed & Breakfast', 'Boat', 'Bungalow', 'Cabin',
#                   'Camper/RV', 'Chalet', 'Condominium', 'Dorm', 'House',
#                   'Loft', 'Other', 'Tent', 'Townhouse', 'Treehouse', 'Yurt'],
# , ordered=False)

# %%
#property type is categorical, so fill missing values with mode
value = listings_subset['property_type'].mode()[0]
print(value)
# Out:
# House

# %%
listings_subset['property_type'].fillna(value, inplace=True)

# %%
listings_subset['property_type'].isna().mean()
# Out:
# 0.0

# %%
#filling missing data with mean values
fill_mean = lambda col: col.fillna(col.mean())
listings_subset[['beds','bathrooms','bedrooms','review_scores_value','reviews_per_month']] = listings_subset[['beds','bathrooms','bedrooms','review_scores_value','reviews_per_month']].apply(fill_mean)

# %%
#q1 -> what are the popular property types which are rented in Seattle
types = listings_subset['property_type'].value_counts().index
types_counts = listings_subset['property_type'].value_counts().values

plot.figure(0,figsize=(10,10))
plot.pie(types_counts, labels=types , autopct= '%1.1f%%')
plot.title('Property Type listings in Seattle')
plot.show()

# %%
#getting more insight on the room type
types = listings_subset['room_type'].value_counts().index
types_counts = listings_subset['room_type'].value_counts().values

plot.figure(0,figsize=(10,10))
plot.pie(types_counts, labels=types , autopct= '%1.1f%%')
plot.title('Room types available for Rent')
plot.show()

# %%
types = listings_subset['bedrooms'].value_counts().index
types_counts = listings_subset['bedrooms'].value_counts().values

plot.figure(0,figsize=(10,10))
plot.pie(types_counts, labels=types , autopct= '%1.1f%%')
plot.title('Most popular bedrooms rented')
plot.show()

# %%
#using bar graphs to depict the better description of the data
#creating bar chart for the Mpost popular bedroom types in Seattle
labels = listings_subset['room_type'].value_counts().index
label_count = listings_subset['room_type'].value_counts().values

fig = plot.figure(0,figsize=(5,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(labels, label_count)
plot.title('Room Type Distribution')
plot.xlabel('Room Type')
plot.ylabel('Total Count')
plot.show()

# %%
#creating bar chart for the Mpost popular bedroom types in Seattle
labels = listings_subset['property_type'].value_counts().index
label_count = listings_subset['property_type'].value_counts().values

fig = plot.figure(0,figsize=(5,5))
ax = fig.add_axes([0,0,1,1])
ax.bar(labels, label_count)
plot.title('Room Type Distribution')
plot.xlabel('Room Type')
plot.ylabel('Total Count')
#aligning the labels so that they dont overlap
plot.setp(ax.get_xticklabels(), rotation=60, horizontalalignment='right')
plot.show()

# %%
#To understand the combinatons, grouping room and property type together
listings_subset.groupby(['room_type','property_type']).agg({'id':'count'})
# Out:
#                                    id
# room_type       property_type
# Entire home/apt Apartment        1428
#                 Bed & Breakfast     3
#                 Boat                4
#                 Bungalow           12
#                 Cabin              16
#                 Camper/RV           9
#                 Chalet              1
#                 Condominium        72
#                 Dorm                0
#                 House             895
#                 Loft               30
#                 Other              12
#                 Tent                3
#                 Townhouse          54
#                 Treehouse           1
#                 Yurt                1
# Private room    Apartment         229
#                 Bed & Breakfast    33
#                 Boat                4
#                 Bungalow            1
#                 Cabin               5
#                 Camper/RV           3
#                 Chalet              1
# ...

# %%
#q2 -> what are most expensive and least expensive months for airbnb

#creating distributing for the months in seattle
#will give relation between most travelled and less travelled
price_per_property = listings_subset.groupby(['property_type']).price.mean()
plot.figure(figsize=(15,15))
price_per_property.plot(kind='barh')
plot.title('Average Price Per Property Type')
plot.xlabel('Average Price')
plot.ylabel('Property Type')
# Out:
# Text(0, 0.5, 'Property Type')

# %%
#we can see that boat is the most expensive to rent for with very high average price, compared to others
#creating a new column in the calendar df to account for all the months
df_calendar['month'] = df_calendar['date'].dt.month

# %%
#Evaluating Average Price per month
price_per_month = df_calendar.groupby(['month']).price.mean()

plot.figure(figsize=(15,15))
price_per_month.plot(kind='line')
plot.title('Average Price Per Property Type')
plot.xlabel('Average Price')
plot.ylabel('Property Type')
# Out:
# Text(0, 0.5, 'Property Type')

# %%
#checking the availability for all the months available to check for the listings

available_per_month = df_calendar.groupby(['month']).available.value_counts()

plot.figure(figsize=(15,15))
available_per_month.plot(kind='bar')
plot.title('Availability')
plot.xlabel('Month')
plot.ylabel('Total Count')
# Out:
# Text(0, 0.5, 'Total Count')

# %%
#Evaluating average price for room type as well
price_per_roomtype = listings_subset.groupby(['room_type']).price.mean()

plot.figure(figsize=(15,15))
price_per_roomtype.plot(kind='bar')
plot.title('Average Price Per Room Type')
plot.xlabel('Room Type')
plot.ylabel('Average Price')
# Out:
# Text(0, 0.5, 'Average Price')

# %%
#q3 -> Most popular neighborhood in seattle
popular_neighborhood = listings_subset['neighbourhood_cleansed'].value_counts()

plot.figure(figsize=(15,15))
popular_neighborhood.plot(kind='barh')
plot.title('Neighborhood')
plot.xlabel('Total Count')
plot.ylabel('Area')
# Out:
# Text(0, 0.5, 'Area')

# %%
#number of reviews per neighboorhood area give better count of what people like to book
plot.figure(figsize=(10,10))
review_count = listings_subset[listings_subset['number_of_reviews']>75]
plot.scatter(review_count['number_of_reviews'], review_count['neighbourhood_cleansed'], marker='.')

# %%
#evaluating the average price for the neighbourhoods
price_neighborhood = listings_subset.groupby(['neighbourhood_cleansed']).price.mean()
plot.figure(figsize=(15,15))
price_neighborhood.plot(kind='barh')
plot.title('Average Price Per Neighbourhood')
plot.xlabel('Average Price')
plot.ylabel('Neighbourhood Area')
# Out:
# Text(0, 0.5, 'Neighbourhood Area')

# %%
#evaluating average price per number of beds available
price_per_bed = listings_subset.groupby(['beds']).price.mean()

plot.figure(figsize=(15,15))
price_per_bed.plot(kind='bar')
plot.title('Average Price Per Bed')
plot.xlabel('Number of Beds')
plot.ylabel('Average Price')
# Out:
# Text(0, 0.5, 'Average Price')

# %%
#Applying Linear Regression model to the dataset
#Before applying the model, we need to figure the important columns for the dataset
#Since we have some outliers in our dataset, we will refine it to have better dataset to train and test
price_df = listings_subset.loc[listings_subset['price']<425]

# %%
#creating numerical values for categorical values in the dataset
price_df['room_type'].replace(to_replace=['Entire home/apt','Private room','Shared room'], value=['1','2','3'], inplace=True)
price_df['room_type'] = price_df['room_type'].astype(str).astype(int)
# Out:
# c:\users\grewa\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py:6619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)
# C:\Users\grewa\AppData\Local\Temp/ipykernel_28964/516750027.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df['room_type'] = price_df['room_type'].astype(str).astype(int)

# %%
price_df['host_is_superhost'].replace(to_replace=['t','f'], value=['1','0'],inplace=True)
price_df['host_is_superhost'] = price_df['host_is_superhost'].astype(str).astype(float)
# Out:
# C:\Users\grewa\AppData\Local\Temp/ipykernel_28964/1331504142.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   price_df['host_is_superhost'] = price_df['host_is_superhost'].astype(str).astype(float)

# %%
price_df.dtypes
# Out:
# id                                         int64
# host_id                                    int64
# host_since                        datetime64[ns]
# host_is_superhost                        float64
# host_listings_count                      float64
# host_total_listings_count                float64
# neighbourhood_cleansed                  category
# latitude                                 float64
# longitude                                float64
# property_type                           category
# room_type                                  int32
# accommodates                               int64
# bathrooms                                float64
# bedrooms                                 float64
# beds                                     float64
# amenities                               category
# price                                    float64
# guests_included                            int64
# minimum_nights                             int64
# ...

# %%
#dropping the categorical columns
price_df = price_df.drop(['host_since','neighbourhood_cleansed','property_type' ,'amenities','cancellation_policy'],axis=1)

# %%
price_df.dtypes
# Out:
# id                                  int64
# host_id                             int64
# host_is_superhost                 float64
# host_listings_count               float64
# host_total_listings_count         float64
# latitude                          float64
# longitude                         float64
# room_type                           int32
# accommodates                        int64
# bathrooms                         float64
# bedrooms                          float64
# beds                              float64
# price                             float64
# guests_included                     int64
# minimum_nights                      int64
# maximum_nights                      int64
# availability_30                     int64
# availability_60                     int64
# availability_90                     int64
# availability_365                    int64
# number_of_reviews                   int64
# review_scores_value               float64
# ...

# %%
#Linear Regression
#Diving into explanatory and responsive variables

X = price_df.drop(['price','id','host_id'],axis=1)
Y = price_df['price']

# %%
#To take care of the NaN and infinite values

X = np.nan_to_num(X)
Y = np.nan_to_num(Y)

# %%
#splitting data into train and testing 
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=42)

# %%
#applying Linear Regression model and then fitting the data
from sklearn.preprocessing import StandardScaler

LM_model = make_pipeline(StandardScaler(with_mean=False), LinearRegression()) 
LM_model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler(with_mean=False)),
#                 ('linearregression', LinearRegression())])

# %%
ytest_pred = LM_model.predict(x_test)
ytrain_pred = LM_model.predict(x_train)

# %%
#evaluating the training and testing score

train_score = r2_score(y_test,ytest_pred)
test_score = r2_score(y_train, ytrain_pred)

# %%
print('The rsquared on training data: {0}, while the rsquared on test data: {1}'.format(train_score, test_score))
# Out:
# The rsquared on training data: 0.5373301952824591, while the rsquared on test data: 0.5933727767185859
